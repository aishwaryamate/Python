# %%
# !pip install pandas

# %%
import pandas

# %%
pandas.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 DataFrame()
#
# NameError: name 'DataFrame' is not defined

# %%
pd.read_csv('bookstore_sales.csv')
# Out:
#       SaleID                               Book Title        Genre  Price  \
# 0          1    Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1          2      Secured grid-enabled conglomeration          NaN  19.08
# 2          3            Progressive tertiary intranet          NaN   8.14
# 3          4        Reactive next generation capacity          NaN  17.94
# 4          5      Multi-channeled asynchronous access          NaN  13.49
# ...      ...                                      ...          ...    ...
# 4995    4996                 Operative impactful core      Fantasy  26.51
# 4996    4997           Upgradable multi-state circuit      Mystery  14.54
# 4997    4998  Mandatory cohesive budgetary management      Fiction  14.01
# 4998    4999        Future-proofed cohesive emulation      Fantasy  35.59
# 4999    5000   Switchable grid-enabled superstructure       Sci-Fi   8.88
#
#       Quantity Sold  Customer Age Customer Gender Purchase Date  \
# ...

# %%
df = pd.read_csv('bookstore_sales.csv')

# %%
df
# Out:
#       SaleID                               Book Title        Genre  Price  \
# 0          1    Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1          2      Secured grid-enabled conglomeration          NaN  19.08
# 2          3            Progressive tertiary intranet          NaN   8.14
# 3          4        Reactive next generation capacity          NaN  17.94
# 4          5      Multi-channeled asynchronous access          NaN  13.49
# ...      ...                                      ...          ...    ...
# 4995    4996                 Operative impactful core      Fantasy  26.51
# 4996    4997           Upgradable multi-state circuit      Mystery  14.54
# 4997    4998  Mandatory cohesive budgetary management      Fiction  14.01
# 4998    4999        Future-proofed cohesive emulation      Fantasy  35.59
# 4999    5000   Switchable grid-enabled superstructure       Sci-Fi   8.88
#
#       Quantity Sold  Customer Age Customer Gender Purchase Date  \
# ...

# %% [markdown]
# # Descriptive Stats

# %%
df.head(25)
# Out:
#     SaleID                                     Book Title        Genre  Price  \
# 0        1          Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1        2            Secured grid-enabled conglomeration          NaN  19.08
# 2        3                  Progressive tertiary intranet          NaN   8.14
# 3        4              Reactive next generation capacity          NaN  17.94
# 4        5            Multi-channeled asynchronous access          NaN  13.49
# 5        6  Triple-buffered incremental Graphic Interface          NaN  11.23
# 6        7         Open-source foreground functionalities       Sci-Fi  46.44
# 7        8              Realigned clear-thinking hardware      Mystery  40.58
# 8        9            Balanced next generation encryption      Mystery  15.39
# 9       10            Persevering dedicated knowledgebase      Fantasy  28.53
# 10      11               Re-engineered real-time database      Fantasy  19.81
# ...

# %%
df.tail()
# Out:
#       SaleID                               Book Title    Genre  Price  \
# 4995    4996                 Operative impactful core  Fantasy  26.51
# 4996    4997           Upgradable multi-state circuit  Mystery  14.54
# 4997    4998  Mandatory cohesive budgetary management  Fiction  14.01
# 4998    4999        Future-proofed cohesive emulation  Fantasy  35.59
# 4999    5000   Switchable grid-enabled superstructure   Sci-Fi   8.88
#
#       Quantity Sold  Customer Age Customer Gender Purchase Date  \
# 4995              4            39          Female     6/14/2023
# 4996              4            44            Male     10/8/2023
# 4997              1            56            Male     9/14/2023
# 4998              1            27            Male     11/5/2022
# 4999              1            37            Male     4/22/2024
#
#      Payment Method Store Location
# 4995    Credit Card        Chicago
# 4996    Credit Card          Miami
# 4997         PayPal          Miami
# ...

# %%
df.describe()
# Out:
#             SaleID        Price  Quantity Sold  Customer Age
# count  5000.000000  5000.000000    5000.000000   5000.000000
# mean   2500.500000    27.345698       2.972800     44.343400
# std    1443.520003    12.965673       1.411686     15.253288
# min       1.000000     5.010000       1.000000     18.000000
# 25%    1250.750000    16.127500       2.000000     31.000000
# 50%    2500.500000    27.060000       3.000000     45.000000
# 75%    3750.250000    38.530000       4.000000     58.000000
# max    5000.000000    49.980000       5.000000     70.000000

# %%
df.describe(include = object)
# Out:
#                                   Book Title   Genre Customer Gender  \
# count                                   5000    4995            5000
# unique                                  4987       6               2
# top     Operative demand-driven installation  Sci-Fi            Male
# freq                                       2     845            2521
#
#        Purchase Date Payment Method Store Location
# count           5000           5000           5000
# unique           992              3              5
# top         8/3/2022         PayPal          Miami
# freq              13           1733           1032

# %%
df.head()
# Out:
#    SaleID                             Book Title        Genre  Price  \
# 0       1  Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1       2    Secured grid-enabled conglomeration          NaN  19.08
# 2       3          Progressive tertiary intranet          NaN   8.14
# 3       4      Reactive next generation capacity          NaN  17.94
# 4       5    Multi-channeled asynchronous access          NaN  13.49
#
#    Quantity Sold  Customer Age Customer Gender Purchase Date Payment Method  \
# 0              2            65          Female     7/26/2023           Cash
# 1              4            34            Male     6/10/2023    Credit Card
# 2              4            21            Male     4/26/2024         PayPal
# 3              5            22          Female     8/21/2022         PayPal
# 4              3            21          Female      1/4/2022         PayPal
#
#   Store Location
# 0             LA
# 1        Seattle
# 2        Seattle
# 3        Chicago
# ...

# %%
df.drop(columns=['SaleID'])
# Out:
#                                    Book Title        Genre  Price  \
# 0       Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1         Secured grid-enabled conglomeration          NaN  19.08
# 2               Progressive tertiary intranet          NaN   8.14
# 3           Reactive next generation capacity          NaN  17.94
# 4         Multi-channeled asynchronous access          NaN  13.49
# ...                                       ...          ...    ...
# 4995                 Operative impactful core      Fantasy  26.51
# 4996           Upgradable multi-state circuit      Mystery  14.54
# 4997  Mandatory cohesive budgetary management      Fiction  14.01
# 4998        Future-proofed cohesive emulation      Fantasy  35.59
# 4999   Switchable grid-enabled superstructure       Sci-Fi   8.88
#
#       Quantity Sold  Customer Age Customer Gender Purchase Date  \
# 0                 2            65          Female     7/26/2023
# ...

# %%
df
# Out:
#       SaleID                               Book Title        Genre  Price  \
# 0          1    Triple-buffered reciprocal complexity  Non-Fiction  17.98
# 1          2      Secured grid-enabled conglomeration          NaN  19.08
# 2          3            Progressive tertiary intranet          NaN   8.14
# 3          4        Reactive next generation capacity          NaN  17.94
# 4          5      Multi-channeled asynchronous access          NaN  13.49
# ...      ...                                      ...          ...    ...
# 4995    4996                 Operative impactful core      Fantasy  26.51
# 4996    4997           Upgradable multi-state circuit      Mystery  14.54
# 4997    4998  Mandatory cohesive budgetary management      Fiction  14.01
# 4998    4999        Future-proofed cohesive emulation      Fantasy  35.59
# 4999    5000   Switchable grid-enabled superstructure       Sci-Fi   8.88
#
#       Quantity Sold  Customer Age Customer Gender Purchase Date  \
# ...

# %%
df.drop(columns=['SaleID'], inplace=True)

# %%
df.head()
# Out:
#                               Book Title        Genre  Price  Quantity Sold  \
# 0  Triple-buffered reciprocal complexity  Non-Fiction  17.98              2
# 1    Secured grid-enabled conglomeration          NaN  19.08              4
# 2          Progressive tertiary intranet          NaN   8.14              4
# 3      Reactive next generation capacity          NaN  17.94              5
# 4    Multi-channeled asynchronous access          NaN  13.49              3
#
#    Customer Age Customer Gender Purchase Date Payment Method Store Location
# 0            65          Female     7/26/2023           Cash             LA
# 1            34            Male     6/10/2023    Credit Card        Seattle
# 2            21            Male     4/26/2024         PayPal        Seattle
# 3            22          Female     8/21/2022         PayPal        Chicago
# 4            21          Female      1/4/2022         PayPal        Seattle

# %%
df['Genre']   #Extracting columns from data
# Out:
# 0       Non-Fiction
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 4995        Fantasy
# 4996        Mystery
# 4997        Fiction
# 4998        Fantasy
# 4999         Sci-Fi
# Name: Genre, Length: 5000, dtype: object

# %%
df[['Genre','Store Location']]
# Out:
#             Genre Store Location
# 0     Non-Fiction             LA
# 1             NaN        Seattle
# 2             NaN        Seattle
# 3             NaN        Chicago
# 4             NaN        Seattle
# ...           ...            ...
# 4995      Fantasy        Chicago
# 4996      Mystery          Miami
# 4997      Fiction          Miami
# 4998      Fantasy        Chicago
# 4999       Sci-Fi             NY
#
# [5000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Book Title       5000 non-null   object
#  1   Genre            4995 non-null   object
#  2   Price            5000 non-null   float64
#  3   Quantity Sold    5000 non-null   int64
#  4   Customer Age     5000 non-null   int64
#  5   Customer Gender  5000 non-null   object
#  6   Purchase Date    5000 non-null   object
#  7   Payment Method   5000 non-null   object
#  8   Store Location   5000 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 351.7+ KB

# %% [markdown]
# # Missing value imputation

# %%
df.isna().sum()
# Out:
# Book Title         0
# Genre              5
# Price              0
# Quantity Sold      0
# Customer Age       0
# Customer Gender    0
# Purchase Date      0
# Payment Method     0
# Store Location     0
# dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Sci-Fi         845
# Biography      845
# Fiction        834
# Fantasy        832
# Non-Fiction    829
# Mystery        810
# Name: count, dtype: int64

# %%
df['Genre'].mode()
# Out:
# 0    Biography
# 1       Sci-Fi
# Name: Genre, dtype: object

# %%
df['Genre'].mode()[0]
# Out:
# 'Biography'

# %%
df.head()
# Out:
#                               Book Title        Genre  Price  Quantity Sold  \
# 0  Triple-buffered reciprocal complexity  Non-Fiction  17.98              2
# 1    Secured grid-enabled conglomeration          NaN  19.08              4
# 2          Progressive tertiary intranet          NaN   8.14              4
# 3      Reactive next generation capacity          NaN  17.94              5
# 4    Multi-channeled asynchronous access          NaN  13.49              3
#
#    Customer Age Customer Gender Purchase Date Payment Method Store Location
# 0            65          Female     7/26/2023           Cash             LA
# 1            34            Male     6/10/2023    Credit Card        Seattle
# 2            21            Male     4/26/2024         PayPal        Seattle
# 3            22          Female     8/21/2022         PayPal        Chicago
# 4            21          Female      1/4/2022         PayPal        Seattle

# %%
df['Genre'].fillna('Biography', inplace=True)

# %%
df.isna().sum()
# Out:
# Book Title         0
# Genre              0
# Price              0
# Quantity Sold      0
# Customer Age       0
# Customer Gender    0
# Purchase Date      0
# Payment Method     0
# Store Location     0
# dtype: int64

# %%
df.head()
# Out:
#                               Book Title        Genre  Price  Quantity Sold  \
# 0  Triple-buffered reciprocal complexity  Non-Fiction  17.98              2
# 1    Secured grid-enabled conglomeration    Biography  19.08              4
# 2          Progressive tertiary intranet    Biography   8.14              4
# 3      Reactive next generation capacity    Biography  17.94              5
# 4    Multi-channeled asynchronous access    Biography  13.49              3
#
#    Customer Age Customer Gender Purchase Date Payment Method Store Location
# 0            65          Female     7/26/2023           Cash             LA
# 1            34            Male     6/10/2023    Credit Card        Seattle
# 2            21            Male     4/26/2024         PayPal        Seattle
# 3            22          Female     8/21/2022         PayPal        Chicago
# 4            21          Female      1/4/2022         PayPal        Seattle

# %% [markdown]
# # Object column functions

# %%
df.head()
# Out:
#                               Book Title        Genre  Price  Quantity Sold  \
# 0  Triple-buffered reciprocal complexity  Non-Fiction  17.98              2
# 1    Secured grid-enabled conglomeration    Biography  19.08              4
# 2          Progressive tertiary intranet    Biography   8.14              4
# 3      Reactive next generation capacity    Biography  17.94              5
# 4    Multi-channeled asynchronous access    Biography  13.49              3
#
#    Customer Age Customer Gender Purchase Date Payment Method Store Location
# 0            65          Female     7/26/2023           Cash             LA
# 1            34            Male     6/10/2023    Credit Card        Seattle
# 2            21            Male     4/26/2024         PayPal        Seattle
# 3            22          Female     8/21/2022         PayPal        Chicago
# 4            21          Female      1/4/2022         PayPal        Seattle

# %%
df['Genre'].unique()
# Out:
# array(['Non-Fiction', 'Biography', 'Sci-Fi', 'Mystery', 'Fantasy',
#        'Fiction'], dtype=object)

# %%
df['Book Title'].unique()
# Out:
# array(['Triple-buffered reciprocal complexity',
#        'Secured grid-enabled conglomeration',
#        'Progressive tertiary intranet', ...,
#        'Mandatory cohesive budgetary management',
#        'Future-proofed cohesive emulation',
#        'Switchable grid-enabled superstructure'], dtype=object)

# %%
df['Book Title'].nunique()
# Out:
# 4987

# %%
df['Payment Method'].unique()
# Out:
# array(['Cash', 'Credit Card', 'PayPal'], dtype=object)

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# PayPal         1733
# Credit Card    1634
# Cash           1633
# Name: count, dtype: int64

# %% [markdown]
# # Pandas Filtering

# %%
df = pd.read_excel('Employees.xlsx')
df

# %%
df['Country'] == 'Lebanon'

# %%
df[df['Country'] == 'Lebanon']

# %%
df[(df['Country'] == 'Lebanon') & (df['Department'] == 'Quality Assurance')]

# %% [markdown]
# # Groupby

# %%
df.groupby('Department')

# %%
df.groupby('Department')['Annual Salary'].mean()

# %%
df.groupby('Center')['Annual Salary'].agg(['min','max','mean'])
