# %% [markdown]
# # Scatter Plots
# - Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system. The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis. These plots are often called scatter graphs or scatter diagrams.
# - A scatter plot is also called a scatter chart, scattergram, or scatter plot, XY graph. The scatter diagram graphs numerical data pairs, with one variable on each axis, show their relationship. Now the question comes for everyone: when to use a scatter plot?
#
# **Scatter plots are used in either of the following situations.**
# - When we have paired numerical data
# - When there are multiple values of the dependent variable for a unique value of an independent variable
# - In determining the relationship between variables in some scenarios, such as identifying potential root causes of problems, checking whether two products that appear to be related both occur with the exact cause and so on.
#
# **We can directly look at scatter plots to check the relationship between 2 variables**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
a = np.linspace(10,200,500)
b = np.random.random_sample(500)


print(len(a))
len(b)
# Out:
# 500
# 500

# %%
#Basic scatter plot

# %%
plt.scatter(a,b)

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

# %%
plt.scatter(a,b, color = 'r', edgecolors='blue')
plt.xlabel('X- axis')
plt.ylabel('Y- axis')
plt.title('A vs B')
# Out:
# Text(0.5, 1.0, 'A vs B')

# %%
#Wine Dataset

# %%
df = pd.read_csv(r"C:\Users\Aishwarya\Desktop\Datasets\Wine.csv")
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1
# 2   3.17     1185                 1
# 3   3.45     1480                 1
# 4   2.93      735                 1

# %%
plt.scatter(df['Flavanoids'], df['Color_Intensity'])

# %%
#linewidth, color,edgecolor

# %%
plt.scatter(df['Flavanoids'],df['Ash_Alcanity'],color = 'g',linewidths=5,alpha=0.5)

# %%
#load sample data

# %%
df = pd.read_csv('sample_data.csv', index_col=0)
df.head()
# Out:
#    Study_Hrs  Marks  Screen_time
# 0        1.0     50          9.0
# 1        2.5     55          8.5
# 2        3.5     60          8.0
# 3        5.5     67          7.5
# 4        6.0     70          6.0

# %%
plt.scatter(df['Study_Hrs'],df['Marks'])

# %%
plt.scatter(df['Screen_time'],df['Marks'])

# %% [markdown]
# **Seaborn Scatterplot**

# %%
#read data

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# 2        154        19           26  16500
# 3        102        24           30  13950
# 4        115        18           22  17450

# %%
#Set style and theme for scatterplot

# %%
sns.set_theme(style='darkgrid')

# %%
sns.scatterplot(df['price'],df['engine-size'],color = 'y', edgecolor = 'black')
# Out:
# <AxesSubplot:xlabel='price', ylabel='engine-size'>

# %%
sns.scatterplot(df['price'],df['engine-size'],color = 'c', edgecolor = 'black',hue=df['engine-location'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='engine-size'>

# %%
sns.scatterplot(df['price'],df['engine-size'],color = 'c', edgecolor = 'black',hue=df['fuel-type'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='engine-size'>

# %%
sns.scatterplot(df['price'],df['engine-size'],edgecolor = 'black',hue=df['body-style'])
plt.xlabel("Price")
plt.ylabel('Engine Size')
plt.title('Price vs Engine Size',size = 25)
# Out:
# Text(0.5, 1.0, 'Price vs Engine Size')

# %% [markdown]
# # 3D Scatterplot

# %%
import plotly.express as px

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# 2        154        19           26  16500
# 3        102        24           30  13950
# 4        115        18           22  17450

# %%
fig = px.scatter_3d(x = 'price', y = 'engine-size', z ='width',data_frame = df,color='make',size_max=15)
fig.show()
# Out:
# <div>                            <div id="03db4039-cd46-4a72-87ff-9cea89c1e93b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03db4039-cd46-4a72-87ff-9cea89c1e93b")) {                    Plotly.newPlot(                        "03db4039-cd46-4a72-87ff-9cea89c1e93b",                        [{"hovertemplate":"make=alfa-romero<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"alfa-romero","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"alfa-romero","scene":"scene","showlegend":true,"x":[13495,16500,16500],"y":[130,130,152],"z":[64.1,64.1,65.5],"type":"scatter3d"},{"hovertemplate":"make=audi<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"audi","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"audi","scene":"scene","showlegend":true,"x":[13950,17450,15250,17710,18920,23875,12000],"y":[109,136,136,136,136,131,131],"z":[66.2,66.4,66.3,71.4,71.4,71.4,67.9],"type":"scatter3d"},{"hovertemplate":"make=bmw<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"bmw","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"bmw","scene":"scene","showlegend":true,"x":[16430,16925,20970,21105,24565,30760,41315,36880],"y":[108,108,164,164,164,209,209,209],"z":[64.8,64.8,64.8,64.8,66.9,66.9,67.9,70.9],"type":"scatter3d"},{"hovertemplate":"make=chevrolet<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"chevrolet","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"chevrolet","scene":"scene","showlegend":true,"x":[5151,6295,6575],"y":[61,90,90],"z":[60.3,63.6,63.6],"type":"scatter3d"},{"hovertemplate":"make=dodge<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"dodge","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"dodge","scene":"scene","showlegend":true,"x":[5572,6377,7957,6229,6692,7609,8558,8921,12964],"y":[90,90,98,90,90,90,98,122,156],"z":[63.8,63.8,63.8,63.8,63.8,63.8,63.8,64.6,66.3],"type":"scatter3d"},{"hovertemplate":"make=honda<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"honda","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"honda","scene":"scene","showlegend":true,"x":[6479,6855,5399,6529,7129,7295,7295,7895,9095,8845,10295,12945,10345],"y":[92,92,79,92,92,92,92,110,110,110,110,110,110],"z":[63.9,63.9,64.0,64.0,64.0,64.0,63.9,65.2,65.2,65.2,62.5,65.2,66.0],"type":"scatter3d"},{"hovertemplate":"make=isuzu<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"isuzu","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"isuzu","scene":"scene","showlegend":true,"x":[6785,10000,23000,11048],"y":[111,90,90,119],"z":[61.8,63.6,63.6,65.2],"type":"scatter3d"},{"hovertemplate":"make=jaguar<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"jaguar","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"jaguar","scene":"scene","showlegend":true,"x":[32250,35550,36000],"y":[258,258,326],"z":[69.6,69.6,70.6],"type":"scatter3d"},{"hovertemplate":"make=mazda<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","legendgroup":"mazda","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"mazda","scene":"scene","showlegend":true,"x":[5195,6095,6795,6695,7395,10945,11845,13645,15645,8845,8495,10595,10245,10795,11245,18280,18344],"y":[91,91,91,91,91,70,70,70,80,122,122,122,122,122,122,140,134],"z":[64.2,64.2,64.2,64.2,64.2,65.7,65.7,65.7,65.7,66.5,66.5,66.5,66.5,66.5,66.5,66.1,66.1],"type":"scatter3d"},{"hovertemplate":"make=mercedes-benz<br>price=%{x}<br>engine-size=%{y}<br>width=%{z}<extra></extra>","l ...
